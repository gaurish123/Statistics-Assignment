# %%
# %matplotlib inline
##Obtain a Data Dictionary
# Data fields
# Here's a brief version of what you'll find in the data description file.

# SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# MSSubClass: The building class
# MSZoning: The general zoning classification
# LotFrontage: Linear feet of street connected to property
# LotArea: Lot size in square feet
# Street: Type of road access
# Alley: Type of alley access
# LotShape: General shape of property
# LandContour: Flatness of the property
# Utilities: Type of utilities available
# LotConfig: Lot configuration
# LandSlope: Slope of property
# Neighborhood: Physical locations within Ames city limits
# Condition1: Proximity to main road or railroad
# Condition2: Proximity to main road or railroad (if a second is present)
# BldgType: Type of dwelling
# HouseStyle: Style of dwelling
# OverallQual: Overall material and finish quality
# OverallCond: Overall condition rating
# YearBuilt: Original construction date
# YearRemodAdd: Remodel date
# RoofStyle: Type of roof
# RoofMatl: Roof material
# Exterior1st: Exterior covering on house
# Exterior2nd: Exterior covering on house (if more than one material)
# MasVnrType: Masonry veneer type
# MasVnrArea: Masonry veneer area in square feet
# ExterQual: Exterior material quality
# ExterCond: Present condition of the material on the exterior
# Foundation: Type of foundation
# BsmtQual: Height of the basement
# BsmtCond: General condition of the basement
# BsmtExposure: Walkout or garden level basement walls
# BsmtFinType1: Quality of basement finished area
# BsmtFinSF1: Type 1 finished square feet
# BsmtFinType2: Quality of second finished area (if present)
# BsmtFinSF2: Type 2 finished square feet
# BsmtUnfSF: Unfinished square feet of basement area
# TotalBsmtSF: Total square feet of basement area
# Heating: Type of heating
# HeatingQC: Heating quality and condition
# CentralAir: Central air conditioning
# Electrical: Electrical system
# 1stFlrSF: First Floor square feet
# 2ndFlrSF: Second floor square feet
# LowQualFinSF: Low quality finished square feet (all floors)
# GrLivArea: Above grade (ground) living area square feet
# BsmtFullBath: Basement full bathrooms
# BsmtHalfBath: Basement half bathrooms
# FullBath: Full bathrooms above grade
# HalfBath: Half baths above grade
# Bedroom: Number of bedrooms above basement level
# Kitchen: Number of kitchens
# KitchenQual: Kitchen quality
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# Functional: Home functionality rating
# Fireplaces: Number of fireplaces
# FireplaceQu: Fireplace quality
# GarageType: Garage location
# GarageYrBlt: Year garage was built
# GarageFinish: Interior finish of the garage
# GarageCars: Size of garage in car capacity
# GarageArea: Size of garage in square feet
# GarageQual: Garage quality
# GarageCond: Garage condition
# PavedDrive: Paved driveway
# WoodDeckSF: Wood deck area in square feet
# OpenPorchSF: Open porch area in square feet
# EnclosedPorch: Enclosed porch area in square feet
# 3SsnPorch: Three season porch area in square feet
# ScreenPorch: Screen porch area in square feet
# PoolArea: Pool area in square feet
# PoolQC: Pool quality
# Fence: Fence quality
# MiscFeature: Miscellaneous feature not covered in other categories
# MiscVal: $Value of miscellaneous feature
# MoSold: Month Sold
# YrSold: Year Sold
# SaleType: Type of sale
# SaleCondition: Condition of sale

# %%
#necessary libraries

import pandas as pd
import numpy as np
import scipy as scipy
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\Lenovo\\Desktop\\ML\\pds\\Assignment1.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1455         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1456         Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 1457         Lvl    AllPub    ...            0    NaN  GdPrv        Shed
# 1458         Lvl    AllPub    ...            0    NaN    NaN         NaN
# 1459         Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
print(df.isnull().sum()[df.isnull().sum()>0])
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
#removing columns which has too much NaN values
df2 = df[[column for column in df if df[column].count() / len(df) >= 0.3]]
del df2['Id']
print("List of dropped columns:", end=" ")
for c in df.columns:
    if c not in df2.columns:
        print(c, end=", ")
print('\n')
df = df2
del df2
# Out:
# List of dropped columns: Id, Alley, PoolQC, Fence, MiscFeature,

# %%
print(df.isnull().sum()[df.isnull().sum()>0])
# Out:
# LotFrontage     259
# MasVnrType        8
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# FireplaceQu     690
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
#                  ...
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# ...

# %%
print(df['SalePrice'].describe())
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['SalePrice'], color='g', bins=100, hist_kws={'alpha': 0.4});
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.distplot(df['SalePrice'], color = "orange", kde = False)
plt.xlabel("log(1+price)")

# %%
#Test for normality
shapiro_results = scipy.stats.shapiro(df.SalePrice)
print("the shapiro test test statistic is {} and the p value is {} ".format(shapiro_results[0],shapiro_results[1]))
# Out:
# the shapiro test test statistic is 0.869671642780304 and the p value is 3.206247534576162e-33

# %%
set(df.dtypes.tolist())
# Out:
# {dtype('int64'), dtype('float64'), dtype('O')}

# %%
# convert the year field from an integer to an object
df['YearBuilt'] = df['YearBuilt'].astype('object')
print(df['YearBuilt'].dtype)
#YearRemodAdd
df['YearRemodAdd'] = df['YearRemodAdd'].astype('object')
print(df['YearRemodAdd'].dtype)
#YrSold
df['YrSold'] = df['YrSold'].astype('object')
print(df['YrSold'].dtype)
# GarageYrBlt
df['GarageYrBlt'] = df['GarageYrBlt'].astype('object')
print(df['GarageYrBlt'].dtype)
#MSSubClass
df['MSSubClass'] = df['MSSubClass'].astype('object')
print(df['MSSubClass'].dtype)
#OverallQual
df['OverallQual'] = df['OverallQual'].astype('object')
print(df['OverallQual'].dtype)
#OverallCond
df['OverallCond'] = df['OverallCond'].astype('object')
print(df['OverallCond'].dtype)
#FullBath
df['FullBath'] = df['FullBath'].astype('object')
print(df['FullBath'].dtype)
#TotRmsAbvGrd: 
df['TotRmsAbvGrd'] = df['TotRmsAbvGrd'].astype('object')
print(df['TotRmsAbvGrd'].dtype)
#Garage Cars
df['GarageCars'] = df['GarageCars'].astype('object')
print(df['GarageCars'].dtype)
#MoSold
df['MoSold'] = df['MoSold'].astype('object')
print(df['MoSold'].dtype)
#BsmtFullBath: 
df['BsmtFullBath'] = df['BsmtFullBath'].astype('object')
print(df['BsmtFullBath'].dtype)
#BsmtHalfBath: 
df['BsmtHalfBath'] = df['BsmtHalfBath'].astype('object')
print(df['BsmtHalfBath'].dtype)
#HalfBath
df['HalfBath'] = df['HalfBath'].astype('object')
print(df['HalfBath'].dtype)
#FullBath
df['FullBath'] = df['FullBath'].astype('object')
print(df['FullBath'].dtype)
#FireplaceQu
df['FireplaceQu'] = df['FireplaceQu'].astype('object')
print(df['FireplaceQu'].dtype)
#BedroomAbvGr
df['BedroomAbvGr'] = df['BedroomAbvGr'].astype('object')
print(df['BedroomAbvGr'].dtype)
#KitchenAbvGr
df['KitchenAbvGr'] = df['KitchenAbvGr'].astype('object')
print(df['KitchenAbvGr'].dtype)
#Fireplaces
df['Fireplaces'] = df['Fireplaces'].astype('object')
print(df['Fireplaces'].dtype)
# Out:
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
df_numeric = df.select_dtypes(include = ['float64','int64'])
df_numeric.describe()
# Out:
#        LotFrontage        LotArea   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1201.000000    1460.000000  1452.000000  1460.000000  1460.000000
# mean     70.049958   10516.828082   103.685262   443.639726    46.549315
# std      24.284752    9981.264932   181.066207   456.098091   161.319273
# min      21.000000    1300.000000     0.000000     0.000000     0.000000
# 25%      59.000000    7553.500000     0.000000     0.000000     0.000000
# 50%      69.000000    9478.500000     0.000000   383.500000     0.000000
# 75%      80.000000   11601.500000   166.000000   712.250000     0.000000
# max     313.000000  215245.000000  1600.000000  5644.000000  1474.000000
#
#          BsmtUnfSF  TotalBsmtSF     1stFlrSF     2ndFlrSF  LowQualFinSF  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000
# mean    567.240411  1057.429452  1162.626712   346.992466      5.844521
# std     441.866955   438.705324   386.587738   436.528436     48.623081
# ...

# %%
df_obj= df.select_dtypes(include = ['object','O'])
df_obj.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460         1460       1460      ...            1379
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1379       1379       1379       1460      7    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Gd  MnPrv
# ...

# %%
plt.figure()
df_numeric.hist(figsize=(16,20), bins=50, xlabelsize=8, ylabelsize=8) 
plt.show()

# %%
#Number of NA values in Reg values
print(df_numeric.isnull().sum()[df_numeric.isnull().sum()>0])
# Out:
# Series([], dtype: int64)

# %%
# fill missing values with mean column values
df_numeric.fillna(df_numeric.mean(), inplace=True)
# count the number of NaN values in each column
print(df_numeric.isnull().sum())
# Out:
# C:\Users\Lenovo\Anaconda3\lib\site-packages\pandas\core\generic.py:3549: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# LotFrontage      0
# LotArea          0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# SalePrice        0
# dtype: int64

# %%
fig, axes = plt.subplots(round(len(df_obj.columns) / 3), 3, figsize=(12, 30))

for i, ax in enumerate(fig.axes):
    if i < len(df_obj.columns):
        ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=90)
        sns.countplot(x=df_obj.columns[i], alpha=0.7, data=df_obj, ax=ax)

fig.tight_layout()

# %%
df_obj.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))

sns.countplot(x="YearBuilt", data=df_obj,alpha = 0.7 )
ax.set_xticklabels(ax.xaxis.get_majorticklabels(), rotation=0)
plt.show()

# %%
df_obj_sale=df[['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
       'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
       'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
       'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
       'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'YrSold',
       'SaleType', 'SaleCondition','SalePrice']]
df_obj_sale

plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='BsmtExposure', y='SalePrice', data=df_obj_sale)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3]), <a list of 4 Text xticklabel objects>)

# %%
#Further checking for co-relation
df_numeric_corr = df_numeric.corr()['SalePrice'][:-1] # -1 because the latest row is SalePrice
high_corr= df_numeric_corr[abs(df_numeric_corr) > 0.3].sort_values(ascending=False)
print("Features with high correlation \n", high_corr)
# Out:
# Features with high correlation
#  GrLivArea      0.708624
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# MasVnrArea     0.475241
# BsmtFinSF1     0.386420
# LotFrontage    0.334901
# WoodDeckSF     0.324413
# 2ndFlrSF       0.319334
# OpenPorchSF    0.315856
# Name: SalePrice, dtype: float64

# %%
#Further checking for co-relation
df = df.corr()['SalePrice'][:-1] # -1 because the latest row is SalePrice
high_corr= df[abs(df) > 0.3].sort_values(ascending=False)
print("Features with high correlation \n", high_corr)
# Out:
# Features with high correlation
#  GrLivArea      0.708624
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# MasVnrArea     0.477493
# BsmtFinSF1     0.386420
# LotFrontage    0.351799
# WoodDeckSF     0.324413
# 2ndFlrSF       0.319334
# OpenPorchSF    0.315856
# Name: SalePrice, dtype: float64

# %%
#pair plot
for i in range(0, len(df_numeric.columns), 5):
    sns.pairplot(data=df_numeric,
                x_vars=df_numeric.columns[i:i+5],
                y_vars=['SalePrice'])

# %%
#df_numeric_sd = df_numeric.drop('SalePrice', axis=1).corr() # We already examined SalePrice correlations
df_numeric_sd = df_numeric.corr()
plt.figure(figsize=(12, 10))

sns.heatmap(df_numeric_sd[(df_numeric_sd >= 0.5) | (df_numeric_sd <= -0.4)], 
            cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True);

# %%
#df_numeric_sd_full = df_numeric.drop('SalePrice', axis=1).corr() # We already examined SalePrice correlations
df_numeric_sd = df_numeric.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(df_numeric.corr(),cmap='viridis',annot=True)
#sns.heatmap(df_numeric_sd[(df_numeric_sd_full >= 0) | (df_numeric_sd_full <= 0)], 
 #           cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
  #          annot=True, annot_kws={"size": 8}, square=True);

# %%
final_chart = [x for x in df_numeric.columns if x in high_corr]
final_chart.append('SalePrice')
final_chart
# Out:
# ['TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'GarageArea', 'SalePrice']

# %%
fig, ax = plt.subplots(round(len(final_chart) / 3), 3, figsize = (18, 12))

for i, ax in enumerate(fig.axes):
    if i < len(final_chart) - 1:
        sns.regplot(x=final_chart[i],y='SalePrice', data=df[final_chart], ax=ax)

# %%
fig, ax = plt.subplots(round(len(final_chart) / 3), 2, figsize = (36, 24))

for i, ax in enumerate(fig.axes):
    if i < len(final_chart) - 1:
        sns.regplot(x=df_numeric.columns[i],y=df.SalePrice, data=df_numeric[df_numeric.columns], ax=ax)

# %%
for i in range(0,len(df_obj_sale.columns),5):
    plt.figure(figsize = (10, 6))
    ax = sns.boxplot(x=df_obj_sale.columns[i], y='SalePrice', data=df_obj_sale)
    plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
    plt.xticks(rotation=45)

# %%
df_numeric_temp = df_numeric.drop('SalePrice',axis=1)

# Import `RandomForestClassifier`
from sklearn.ensemble import RandomForestClassifier

# Isolate Data, class labels and column values
X = df_numeric_temp.iloc[:,0:32]
Y = df_numeric_temp.iloc[:,-1]
names = df_numeric_temp.columns.values

# Build the model
rfc = RandomForestClassifier()

# Fit the model
rfc.fit(X, Y)

# Print the results
print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rfc.feature_importances_), names), reverse=True))
# Out:
# Features sorted by their score:
# [(0.5171, 'MiscVal'), (0.047399999999999998, '1stFlrSF'), (0.044499999999999998, 'LotArea'), (0.043400000000000001, 'GarageArea'), (0.042299999999999997, 'GrLivArea'), (0.038600000000000002, 'BsmtUnfSF'), (0.032000000000000001, 'TotalBsmtSF'), (0.029499999999999998, 'ScreenPorch'), (0.029100000000000001, 'LotFrontage'), (0.028299999999999999, 'BsmtFinSF1'), (0.025999999999999999, 'WoodDeckSF'), (0.024400000000000002, 'EnclosedPorch'), (0.023800000000000002, 'BsmtFinSF2'), (0.021399999999999999, 'MasVnrArea'), (0.015800000000000002, 'OpenPorchSF'), (0.012699999999999999, 'LowQualFinSF'), (0.012, '2ndFlrSF'), (0.0076, '3SsnPorch'), (0.0040000000000000001, 'PoolArea')]

# %%
df_numeric_temp
# Out:
#       LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0       65.000000     8450       196.0         706           0        150
# 1       80.000000     9600         0.0         978           0        284
# 2       68.000000    11250       162.0         486           0        434
# 3       60.000000     9550         0.0         216           0        540
# 4       84.000000    14260       350.0         655           0        490
# 5       85.000000    14115         0.0         732           0         64
# 6       75.000000    10084       186.0        1369           0        317
# 7       70.049958    10382       240.0         859          32        216
# 8       51.000000     6120         0.0           0           0        952
# 9       50.000000     7420         0.0         851           0        140
# 10      70.000000    11200         0.0         906           0        134
# 11      85.000000    11924       286.0         998           0        177
# ...
